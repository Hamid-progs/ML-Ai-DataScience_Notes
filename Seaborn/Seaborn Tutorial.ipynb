# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("ComputerSales.csv")

# %%
df.head()
# Out:
#    Sale ID      Contact Sex  Age State Product ID Product Type  Sale Price  \
# 0        1  Paul Thomas   M   43    OH  M01-F0024      Desktop      479.99
# 1        2  Margo Simms   F   37    WV  GT13-0024      Desktop     1249.99
# 2        3    Sam Stine   M   26    PA      I3670      Desktop      649.99
# 3        4   Moe Eggert   M   35    PA      I3593       Laptop      399.99
# 4        5  Jessica Elk   F   55    PA     15M-ED       Laptop      699.99
#
#    Profit     Lead     Month  Year
# 0  143.39  Website   January  2018
# 1  230.89  Flyer 4   January  2018
# 2  118.64  Website  February  2018
# 3   72.09  Website     March  2018
# 4   98.09  Flyer 4     March  2018

# %%
print(sns.get_dataset_names())   # builtin data set in seaborn
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
carash_df = sns.load_dataset("car_crashes")

# %%
carash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # Distribution plot

# %% [markdown]
# # 1.

# %%
sns.distplot(carash_df['not_distracted'])
plt.show()
# Out:
# C:\Users\AL Rehman Computer\AppData\Local\Temp\ipykernel_15008\2049384390.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(carash_df['not_distracted'])

# %% [markdown]
# # 1.

# %%
sns.distplot(carash_df['not_distracted'],kde= False, bins=25)
plt.show()
# Out:
# C:\Users\AL Rehman Computer\AppData\Local\Temp\ipykernel_15008\4173360316.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(carash_df['not_distracted'],kde= False, bins=25)

# %% [markdown]
# # Joint plot

# %%
sns.jointplot(x='speeding',y='alcohol',data=carash_df,kind='reg')
plt.show()

# %%
sns.jointplot(x='speeding',y='alcohol',data=carash_df,kind='kde')

# %%
sns.jointplot(x='speeding',y='alcohol',data=carash_df,kind='hex')
plt.show()

# %% [markdown]
# # KDE plots

# %%
sns.kdeplot(carash_df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # Pair plots

# %%
sns.pairplot(carash_df)

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips_df,hue='sex',palette='Blues')

# %% [markdown]
# # Rug Plot

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# # styling

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y='alcohol',data=carash_df,kind='reg')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('paper',font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol',data=carash_df,kind='reg')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('talk',font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol',data=carash_df,kind='reg')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('poster',font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol',data=carash_df,kind='reg')
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:1766: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   f.tight_layout()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.set_context('paper',font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol',data=carash_df,kind='reg')
sns.despine(left=True, bottom=True, right= True)

# %% [markdown]
# # Bar plots

# %%
sns.barplot(x='sex',y='total_bill',data= tips_df, estimator=np.mean)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Count plot

# %%
sns.countplot(x='sex',data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # boxplot

# %%
sns.boxplot(x='day',y='total_bill',data=tips_df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(x='day',y='total_bill',data=tips_df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips_df,hue='sex', split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Strip plot

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x='day',y='total_bill',data=tips_df,jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x='day',y='total_bill',data=tips_df,jitter=True, hue='sex', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Swarm plot

# %%
sns.violinplot(x='day',y='total_bill',data=tips_df)
sns.swarmplot(x='day',y='total_bill',data=tips_df,color='white')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # palettes

# %%
plt.figure(figsize=(8,5))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='day',y='total_bill',data=tips_df,hue='sex', palette='magma')
plt.legend(loc=0) # change the location of legends

# %% [markdown]
# # Heatmaps

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
crash = carash_df.drop('abbrev',axis=1)
crash_corr = crash.corr()
sns.heatmap(crash_corr,annot=True,cmap='BuPu')
# Out:
# <Axes: >

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index='month',columns='year',values='passengers')
sns.heatmap(flights,cmap='Blues',linecolor='white',linewidths=1)
# Out:
# C:\Users\AL Rehman Computer\AppData\Local\Temp\ipykernel_15008\2723564200.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights = flights.pivot_table(index='month',columns='year',values='passengers')
# <Axes: xlabel='year', ylabel='month'>

# %%
flights
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %% [markdown]
# # clusters maps

# %%
iris = sns.load_dataset('iris')
species = iris.pop('species')
sns.clustermap(iris)

# %%
sns.clustermap(flights,cmap='Blues',standard_scale=1)

# %% [markdown]
# # pair Grid

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris,hue="species")
iris_g.map(plt.scatter)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris,hue="species")
iris_g.map(plt.scatter)
iris_g.map_diag(plt.hist)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris,hue="species")
iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris,hue="species")
iris_g.map_diag(plt.hist)
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris,hue='species',
                      x_vars=['sepal_length','sepal_width'],
                     y_vars=['sepal_length','sepal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# # Facit grid

# %%
tips_fg = sns.FacetGrid(tips_df,col='time',row='smoker')
tips_fg.map(plt.hist,'total_bill', bins=8)

# %%
tips_fg = sns.FacetGrid(tips_df,col='time',row='smoker')
tips_fg.map(plt.scatter,'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df,col='time',hue='smoker',height=4, aspect=1.3)
tips_fg.map(plt.scatter,'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df,col='time',hue='smoker',height=4, aspect=1.3,col_order=['Dinner','Lunch'],palette='Set1')
tips_fg.map(plt.scatter,'total_bill', 'tip',edgecolor='w')

# %%
kws= dict(s=50 , linewidth=.5, edgecolor='w')
tips_fg = sns.FacetGrid(tips_df,col='sex',hue='smoker',height=4,aspect=1.3,hue_order=['Yes','No'],hue_kws=dict(marker=['^','v']))
tips_fg.map(plt.scatter,'total_bill','tip',**kws)

# %%
att_df = sns.load_dataset('attention')
att_fg = sns.FacetGrid(att_df)

# %% [markdown]
# # Regression Plot

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
sns.lmplot(x='total_bill',y='tip',hue='sex',data=tips_df,markers=['o','^'],
          scatter_kws={'s':100 , 'linewidths':0.5 , 'edgecolor':'white'})
tips_df = sns.load_dataset('tips')

# %%
sns.lmplot(x='total_bill',y='tip',col='sex',row='time',data=tips_df, 
          height=8 , aspect=0.6)
