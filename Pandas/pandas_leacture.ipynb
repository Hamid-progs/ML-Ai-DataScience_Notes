# %% [markdown]
# ### """
# important functions:     pd->pandas
# pd.series()
# pd.DataFrame()
# pd.read_csv("file path")
# nameof_dataframe.head(range of the data)
# nameof_dataframe.to_csv("name to give the new exported file", index = False)
# """

# %%
import pandas as pd

# %%
#1-dimensional Series example
mobile = pd.Series(['samsung','iphone',"Nokia"])
mobile
# Out:
# 0    samsung
# 1     iphone
# 2      Nokia
# dtype: object

# %%
#1-dimensional Series example
bag = pd.Series(['pen','paper','notebook'])
bag
# Out:
# 0         pen
# 1       paper
# 2    notebook
# dtype: object

# %%
#2-dimensional Data : DataFrame example
dataframe = pd.DataFrame({"elecrtronics":mobile,"price":["1-lakh", "2-lakh", "2000"]})
dataframe
# Out:
#   elecrtronics   price
# 0      samsung  1-lakh
# 1       iphone  2-lakh
# 2        Nokia    2000

# %%
#heart_csv is a data frame which stores all the data
heart_csv = pd.read_csv("HeartDiseaseTrain-Test.csv")

# %%
heart_csv.head(10)
# Out:
#    age     sex chest_pain_type  resting_blood_pressure  cholestoral  \
# 0   52    Male  Typical angina                     125          212
# 1   53    Male  Typical angina                     140          203
# 2   70    Male  Typical angina                     145          174
# 3   61    Male  Typical angina                     148          203
# 4   62  Female  Typical angina                     138          294
# 5   58  Female  Typical angina                     100          248
# 6   58    Male  Typical angina                     114          318
# 7   55    Male  Typical angina                     160          289
# 8   46    Male  Typical angina                     120          249
# 9   54    Male  Typical angina                     122          286
#
#       fasting_blood_sugar                      rest_ecg  Max_heart_rate  \
# 0    Lower than 120 mg/ml         ST-T wave abnormality             168
# 1  Greater than 120 mg/ml                        Normal             155
# ...

# %%
#export the csv with new data you processed here.
heart_csv.to_csv("modified heart version 1.csv", index= False) 
"""if you dont write index = False the exsisting index column will also add
in the exported file , which is a glitch  ,,,, we have a example of such file 
let me show you: 
"""
# Out:
# 'if you dont write index = False the exsisting index column will also add\nin the exported file , which is a glitch  ,,,, we have a example of such file \nlet me show you: \n'

# %%
df=pd.read_csv("modified heart.csv")
df.head(10)# below you will see a useless indexing it is because we exported this file 
#without using index = False !!!!
# Out:
#    Unnamed: 0  age     sex chest_pain_type  resting_blood_pressure  \
# 0           0   52    Male  Typical angina                     125
# 1           1   53    Male  Typical angina                     140
# 2           2   70    Male  Typical angina                     145
# 3           3   61    Male  Typical angina                     148
# 4           4   62  Female  Typical angina                     138
# 5           5   58  Female  Typical angina                     100
# 6           6   58    Male  Typical angina                     114
# 7           7   55    Male  Typical angina                     160
# 8           8   46    Male  Typical angina                     120
# 9           9   54    Male  Typical angina                     122
#
#    cholestoral     fasting_blood_sugar                      rest_ecg  \
# 0          212    Lower than 120 mg/ml         ST-T wave abnormality
# 1          203  Greater than 120 mg/ml                        Normal
# ...

# %%
df=pd.read_csv("modified heart version 1.csv")
df.head(10)
# Out:
#    age     sex chest_pain_type  resting_blood_pressure  cholestoral  \
# 0   52    Male  Typical angina                     125          212
# 1   53    Male  Typical angina                     140          203
# 2   70    Male  Typical angina                     145          174
# 3   61    Male  Typical angina                     148          203
# 4   62  Female  Typical angina                     138          294
# 5   58  Female  Typical angina                     100          248
# 6   58    Male  Typical angina                     114          318
# 7   55    Male  Typical angina                     160          289
# 8   46    Male  Typical angina                     120          249
# 9   54    Male  Typical angina                     122          286
#
#       fasting_blood_sugar                      rest_ecg  Max_heart_rate  \
# 0    Lower than 120 mg/ml         ST-T wave abnormality             168
# 1  Greater than 120 mg/ml                        Normal             155
# ...

# %% [markdown]
# ### How to Describe Data!!

# %% [raw]
# #Attributes (without brackets!)
# df.dtypes
# df.columns
# df.index
#                             df stands for data frame ,, there can be any thing else
#                             then df ie. you can give it what ever name you want
# #Function()
# df.describe()
# df.info()
# df.mean()
# df.sum()

# %%
#df=pd.read_csv("modified heart.csv")
df.dtypes
# Out:
# age                                int64
# sex                               object
# chest_pain_type                   object
# resting_blood_pressure             int64
# cholestoral                        int64
# fasting_blood_sugar               object
# rest_ecg                          object
# Max_heart_rate                     int64
# exercise_induced_angina           object
# oldpeak                          float64
# slope                             object
# vessels_colored_by_flourosopy     object
# thalassemia                       object
# target                             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'resting_blood_pressure',
#        'cholestoral', 'fasting_blood_sugar', 'rest_ecg', 'Max_heart_rate',
#        'exercise_induced_angina', 'oldpeak', 'slope',
#        'vessels_colored_by_flourosopy', 'thalassemia', 'target'],
#       dtype='object')

# %%
columns=df.columns
columns
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'resting_blood_pressure',
#        'cholestoral', 'fasting_blood_sugar', 'rest_ecg', 'Max_heart_rate',
#        'exercise_induced_angina', 'oldpeak', 'slope',
#        'vessels_colored_by_flourosopy', 'thalassemia', 'target'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %%
df.describe() #provide staticstical information of int data type columns only
# Out:
#                age  resting_blood_pressure  cholestoral  Max_heart_rate  \
# count  1025.000000             1025.000000   1025.00000     1025.000000
# mean     54.434146              131.611707    246.00000      149.114146
# std       9.072290               17.516718     51.59251       23.005724
# min      29.000000               94.000000    126.00000       71.000000
# 25%      48.000000              120.000000    211.00000      132.000000
# 50%      56.000000              130.000000    240.00000      152.000000
# 75%      61.000000              140.000000    275.00000      166.000000
# max      77.000000              200.000000    564.00000      202.000000
#
#            oldpeak       target
# count  1025.000000  1025.000000
# mean      1.071512     0.513171
# std       1.175053     0.500070
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.800000     1.000000
# 75%       1.800000     1.000000
# max       6.200000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            1025 non-null   int64
#  1   sex                            1025 non-null   object
#  2   chest_pain_type                1025 non-null   object
#  3   resting_blood_pressure         1025 non-null   int64
#  4   cholestoral                    1025 non-null   int64
#  5   fasting_blood_sugar            1025 non-null   object
#  6   rest_ecg                       1025 non-null   object
#  7   Max_heart_rate                 1025 non-null   int64
#  8   exercise_induced_angina        1025 non-null   object
#  9   oldpeak                        1025 non-null   float64
#  10  slope                          1025 non-null   object
#  11  vessels_colored_by_flourosopy  1025 non-null   object
# ...

# %%
test = pd.Series([1,2,3])
print(test)
print(test.mean())
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
# 2.0

# %%
test.sum()
# Out:
# 6

# %%
df["age"].sum()
# Out:
# 55795

# %% [markdown]
# # Data Selection

# %%
df.head()
# Out:
#    age     sex chest_pain_type  resting_blood_pressure  cholestoral  \
# 0   52    Male  Typical angina                     125          212
# 1   53    Male  Typical angina                     140          203
# 2   70    Male  Typical angina                     145          174
# 3   61    Male  Typical angina                     148          203
# 4   62  Female  Typical angina                     138          294
#
#       fasting_blood_sugar               rest_ecg  Max_heart_rate  \
# 0    Lower than 120 mg/ml  ST-T wave abnormality             168
# 1  Greater than 120 mg/ml                 Normal             155
# 2    Lower than 120 mg/ml  ST-T wave abnormality             125
# 3    Lower than 120 mg/ml  ST-T wave abnormality             161
# 4  Greater than 120 mg/ml  ST-T wave abnormality             106
#
#   exercise_induced_angina  oldpeak        slope vessels_colored_by_flourosopy  \
# 0                      No      1.0  Downsloping                           Two
# ...

# %%
df.tail()
# Out:
#       age     sex  chest_pain_type  resting_blood_pressure  cholestoral  \
# 1020   59    Male  Atypical angina                     140          221
# 1021   60    Male   Typical angina                     125          258
# 1022   47    Male   Typical angina                     110          275
# 1023   50  Female   Typical angina                     110          254
# 1024   54    Male   Typical angina                     120          188
#
#        fasting_blood_sugar               rest_ecg  Max_heart_rate  \
# 1020  Lower than 120 mg/ml  ST-T wave abnormality             164
# 1021  Lower than 120 mg/ml                 Normal             141
# 1022  Lower than 120 mg/ml                 Normal             118
# 1023  Lower than 120 mg/ml                 Normal             159
# 1024  Lower than 120 mg/ml  ST-T wave abnormality             113
#
#      exercise_induced_angina  oldpeak        slope  \
# 1020                     Yes      0.0  Downsloping
# ...

# %% [markdown]
# # index (.loc) or location/position (.iloc)

# %% [raw]
# functions:
# .tail()   simillar as head give value from tail of list
# .loc()
# .iloc()

# %%
birds = pd.Series(["eagle","crow","sparrow","unicorn"], index = [0,3,9,4])

# %%
birds
# Out:
# 0      eagle
# 3       crow
# 9    sparrow
# 4    unicorn
# dtype: object

# %%
birds.loc[9]="Owl" #index as 0,3,9,3

# %%
birds
# Out:
# 0      eagle
# 3       crow
# 9        Owl
# 4    unicorn
# dtype: object

# %%
birds.iloc[2] #position as 0,1,2,3
# Out:
# 'Owl'

# %%
birds.iloc[:2]="Sparrow"

# %%
birds
# Out:
# 0    Sparrow
# 3    Sparrow
# 9    Sparrow
# 4    unicorn
# dtype: object

# %%
df.loc[1024]
# Out:
# age                                                 54
# sex                                               Male
# chest_pain_type                         Typical angina
# resting_blood_pressure                             120
# cholestoral                                        188
# fasting_blood_sugar               Lower than 120 mg/ml
# rest_ecg                         ST-T wave abnormality
# Max_heart_rate                                     113
# exercise_induced_angina                             No
# oldpeak                                            1.4
# slope                                             Flat
# vessels_colored_by_flourosopy                      One
# thalassemia                          Reversable Defect
# target                                               0
# Name: 1024, dtype: object

# %%
df.iloc[1024]
# Out:
# age                                                 54
# sex                                               Male
# chest_pain_type                         Typical angina
# resting_blood_pressure                             120
# cholestoral                                        188
# fasting_blood_sugar               Lower than 120 mg/ml
# rest_ecg                         ST-T wave abnormality
# Max_heart_rate                                     113
# exercise_induced_angina                             No
# oldpeak                                            1.4
# slope                                             Flat
# vessels_colored_by_flourosopy                      One
# thalassemia                          Reversable Defect
# target                                               0
# Name: 1024, dtype: object

# %%
df.iloc[:3]   #also  do slicing work as .head()
# Out:
#    age   sex chest_pain_type  resting_blood_pressure  cholestoral  \
# 0   52  Male  Typical angina                     125          212
# 1   53  Male  Typical angina                     140          203
# 2   70  Male  Typical angina                     145          174
#
#       fasting_blood_sugar               rest_ecg  Max_heart_rate  \
# 0    Lower than 120 mg/ml  ST-T wave abnormality             168
# 1  Greater than 120 mg/ml                 Normal             155
# 2    Lower than 120 mg/ml  ST-T wave abnormality             125
#
#   exercise_induced_angina  oldpeak        slope vessels_colored_by_flourosopy  \
# 0                      No      1.0  Downsloping                           Two
# 1                     Yes      3.1    Upsloping                          Zero
# 2                     Yes      2.6    Upsloping                          Zero
#
#          thalassemia  target
# 0  Reversable Defect       0
# 1  Reversable Defect       0
# 2  Reversable Defect       0

# %%
df.head(3)
# Out:
#    age   sex chest_pain_type  resting_blood_pressure  cholestoral  \
# 0   52  Male  Typical angina                     125          212
# 1   53  Male  Typical angina                     140          203
# 2   70  Male  Typical angina                     145          174
#
#       fasting_blood_sugar               rest_ecg  Max_heart_rate  \
# 0    Lower than 120 mg/ml  ST-T wave abnormality             168
# 1  Greater than 120 mg/ml                 Normal             155
# 2    Lower than 120 mg/ml  ST-T wave abnormality             125
#
#   exercise_induced_angina  oldpeak        slope vessels_colored_by_flourosopy  \
# 0                      No      1.0  Downsloping                           Two
# 1                     Yes      3.1    Upsloping                          Zero
# 2                     Yes      2.6    Upsloping                          Zero
#
#          thalassemia  target
# 0  Reversable Defect       0
# 1  Reversable Defect       0
# 2  Reversable Defect       0

# %%
df['fasting_blood_sugar']
# Out:
# 0         Lower than 120 mg/ml
# 1       Greater than 120 mg/ml
# 2         Lower than 120 mg/ml
# 3         Lower than 120 mg/ml
# 4       Greater than 120 mg/ml
#                  ...
# 1020      Lower than 120 mg/ml
# 1021      Lower than 120 mg/ml
# 1022      Lower than 120 mg/ml
# 1023      Lower than 120 mg/ml
# 1024      Lower than 120 mg/ml
# Name: fasting_blood_sugar, Length: 1025, dtype: object

# %%
df.fasting_blood_sugar
# Out:
# 0         Lower than 120 mg/ml
# 1       Greater than 120 mg/ml
# 2         Lower than 120 mg/ml
# 3         Lower than 120 mg/ml
# 4       Greater than 120 mg/ml
#                  ...
# 1020      Lower than 120 mg/ml
# 1021      Lower than 120 mg/ml
# 1022      Lower than 120 mg/ml
# 1023      Lower than 120 mg/ml
# 1024      Lower than 120 mg/ml
# Name: fasting_blood_sugar, Length: 1025, dtype: object

# %% [markdown]
# # Data Selection Part 2

# %% [raw]
# important functions:
# pd.crosstab() for comparision between two columns
# pd.groupby    for comparision between more then two columns

# %%
count=pd.crosstab(df['age'],df["sex"])

# %%
count

# %% [raw]
# df.groupby("sex")["age"].mean()

# %%
df.dtypes
# Out:
# age                                int64
# sex                               object
# chest_pain_type                   object
# resting_blood_pressure             int64
# cholestoral                        int64
# fasting_blood_sugar               object
# rest_ecg                          object
# Max_heart_rate                     int64
# exercise_induced_angina           object
# oldpeak                          float64
# slope                             object
# vessels_colored_by_flourosopy     object
# thalassemia                       object
# target                             int64
# dtype: object

# %% [markdown]
# ###  how to plot a data

# %% [raw]
# ploting libraries should import if ploting doesnt occurs
# %matplotlib inline
# import matplotlib.pyplot as plt

# %%
df['age'].plot()
# Out:
# <Axes: >

# %%
df['age'].hist()
# Out:
# <Axes: >

# %% [raw]
# Gaussian Distributition      (normal distributition)

# %%
import pandas as pd

# %%
price=pd.DataFrame({"items": ["nokia","samsung","iphone",'redme',"xiomi","vivo","itel"],"cost":['$100.00','$200.00','$700.00','$300.00','$500.00','$100.00','$500.00']})

# %%
price["cost"]
# Out:
# 0    $100.00
# 1    $200.00
# 2    $700.00
# 3    $300.00
# 4    $500.00
# 5    $100.00
# 6    $500.00
# Name: cost, dtype: object

# %%
#cleaning the column
price['cost'].str.replace(r"[\$,.]", "", regex=True)
# you can also place .astype() in above statement as 
#cost=price['cost'].str.replace(r"[\$,.]", "", regex=True).astype(int)
# Out:
# 0    10000
# 1    20000
# 2    70000
# 3    30000
# 4    50000
# 5    10000
# 6    50000
# Name: cost, dtype: object

# %%
price['cost']=price['cost'].str.replace(r"[\$,.]", "", regex=True).astype(int)

# %%
price.dtypes
# Out:
# items    object
# cost      int32
# dtype: object

# %%
price["cost"]= price["cost"]/100

# %%
price["cost"] = price["cost"].astype(int)

# %%
price
# Out:
#      items  cost
# 0    nokia   100
# 1  samsung   200
# 2   iphone   700
# 3    redme   300
# 4    xiomi   500
# 5     vivo   100
# 6     itel   500

# %%
price.dtypes
# Out:
# items    object
# cost      int32
# dtype: object

# %%
price.plot()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age     sex chest_pain_type  resting_blood_pressure  cholestoral  \
# 0   52    Male  Typical angina                     125          212
# 1   53    Male  Typical angina                     140          203
# 2   70    Male  Typical angina                     145          174
# 3   61    Male  Typical angina                     148          203
# 4   62  Female  Typical angina                     138          294
#
#       fasting_blood_sugar               rest_ecg  Max_heart_rate  \
# 0    Lower than 120 mg/ml  ST-T wave abnormality             168
# 1  Greater than 120 mg/ml                 Normal             155
# 2    Lower than 120 mg/ml  ST-T wave abnormality             125
# 3    Lower than 120 mg/ml  ST-T wave abnormality             161
# 4  Greater than 120 mg/ml  ST-T wave abnormality             106
#
#   exercise_induced_angina  oldpeak        slope vessels_colored_by_flourosopy  \
# 0                      No      1.0  Downsloping                           Two
# ...

# %% [markdown]
# ###  Changing Data

# %%
df["chest_pain_type"].str.lower()
# Out:
# 0        typical angina
# 1        typical angina
# 2        typical angina
# 3        typical angina
# 4        typical angina
#              ...
# 1020    atypical angina
# 1021     typical angina
# 1022     typical angina
# 1023     typical angina
# 1024     typical angina
# Name: chest_pain_type, Length: 1025, dtype: object

# %%
df["chest_pain_type"]
# Out:
# 0        Typical angina
# 1        Typical angina
# 2        Typical angina
# 3        Typical angina
# 4        Typical angina
#              ...
# 1020    Atypical angina
# 1021     Typical angina
# 1022     Typical angina
# 1023     Typical angina
# 1024     Typical angina
# Name: chest_pain_type, Length: 1025, dtype: object

# %%
df_missing = pd.read_csv("mising_data_md.csv")

# %%
df_missing
# Out:
#      Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  Weight_g  \
# 0  Samsung     Galaxy S21    NaN       4000.0       128.0     8.0     169.0
# 1    Apple      iPhone 13  $899        3227.0       128.0     4.0       NaN
# 2   Xiaomi  Redmi Note 10  $199        5000.0        64.0     NaN     178.0
# 3   Realme       Realme 8  $229        5000.0       128.0     6.0     177.0
# 4     Oppo          Reno6  $449           NaN       128.0     8.0     173.0
# 5     Vivo            Y21  $180        5000.0        64.0     4.0     182.0
# 6  OnePlus          9 Pro  $969        4500.0         NaN    12.0     197.0
# 7  Infinix         Zero X  $250        4500.0       128.0     8.0       NaN
# 8    Tecno       Camon 17  $150        5000.0        64.0     4.0     190.0
# 9    Nokia            G20  $160        5050.0        64.0     NaN     197.0
#
#    Rating
# 0     4.5
# 1     4.7
# 2     4.3
# 3     4.4
# 4     NaN
# 5     4.1
# 6     4.6
# 7     4.0
# 8     3.9
# 9     3.8

# %% [raw]
# df_missing["Price"]=df_missing["Price"].str.replace(r"[\$,]","", regex=True).astype(int)

# %%
df_missing["Rating"].mean()
# Out:
# 4.2555555555555555

# %%
df_missing["Rating"].fillna(df_missing["Rating"].mean(),inplace=True)

# %%
df_missing["Weight_g"].fillna(df_missing["Weight_g"].mean(),inplace=True)
# Out:
# C:\Users\AL Rehman Computer\AppData\Local\Temp\ipykernel_10720\3304323876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_missing["Weight_g"].fillna(df_missing["Weight_g"].mean(),inplace=True)

# %%
df_missing
# Out:
#      Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  Weight_g  \
# 0  Samsung     Galaxy S21    NaN       4000.0       128.0     8.0   169.000
# 1    Apple      iPhone 13  $899        3227.0       128.0     4.0   182.875
# 2   Xiaomi  Redmi Note 10  $199        5000.0        64.0     NaN   178.000
# 3   Realme       Realme 8  $229        5000.0       128.0     6.0   177.000
# 4     Oppo          Reno6  $449           NaN       128.0     8.0   173.000
# 5     Vivo            Y21  $180        5000.0        64.0     4.0   182.000
# 6  OnePlus          9 Pro  $969        4500.0         NaN    12.0   197.000
# 7  Infinix         Zero X  $250        4500.0       128.0     8.0   182.875
# 8    Tecno       Camon 17  $150        5000.0        64.0     4.0   190.000
# 9    Nokia            G20  $160        5050.0        64.0     NaN   197.000
#
#      Rating
# 0  4.500000
# 1  4.700000
# 2  4.300000
# 3  4.400000
# 4  4.255556
# 5  4.100000
# 6  4.600000
# 7  4.000000
# ...

# %%
df_missing["RAM_GB"].fillna(df_missing["RAM_GB"].mean(),inplace=True)
# Out:
# C:\Users\AL Rehman Computer\AppData\Local\Temp\ipykernel_10720\2544505475.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_missing["RAM_GB"].fillna(df_missing["RAM_GB"].mean(),inplace=True)

# %%
df_missing["Storage_GB"].fillna(df_missing["Storage_GB"].mean(),inplace=True)
# Out:
# C:\Users\AL Rehman Computer\AppData\Local\Temp\ipykernel_10720\3047558501.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_missing["Storage_GB"].fillna(df_missing["Storage_GB"].mean(),inplace=True)

# %%
df_missing["Battery_mAh"]=df_missing["Battery_mAh"].fillna(df_missing["Battery_mAh"].mean())

# %%
most_common = df_missing["Price"].mode()[0]
df_missing["Price"] = df_missing["Price"].fillna(most_common)

# %%
df_missing
# Out:
#      Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  Weight_g  \
# 0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00   169.000
# 1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00   182.875
# 2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75   178.000
# 3   Realme       Realme 8  $229   5000.000000  128.000000    6.00   177.000
# 4     Oppo          Reno6  $449   4586.333333  128.000000    8.00   173.000
# 5     Vivo            Y21  $180   5000.000000   64.000000    4.00   182.000
# 6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00   197.000
# 7  Infinix         Zero X  $250   4500.000000  128.000000    8.00   182.875
# 8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00   190.000
# 9    Nokia            G20  $160   5050.000000   64.000000    6.75   197.000
#
#      Rating
# 0  4.500000
# 1  4.700000
# 2  4.300000
# 3  4.400000
# 4  4.255556
# 5  4.100000
# 6  4.600000
# 7  4.000000
# ...

# %%
df_missing.to_csv("Filled_md.csv")

# %%
df=pd.read_csv("Filled_md.csv")

# %%
df
# Out:
#    Unnamed: 0    Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  \
# 0           0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00
# 1           1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00
# 2           2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75
# 3           3   Realme       Realme 8  $229   5000.000000  128.000000    6.00
# 4           4     Oppo          Reno6  $449   4586.333333  128.000000    8.00
# 5           5     Vivo            Y21  $180   5000.000000   64.000000    4.00
# 6           6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00
# 7           7  Infinix         Zero X  $250   4500.000000  128.000000    8.00
# 8           8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00
# 9           9    Nokia            G20  $160   5050.000000   64.000000    6.75
#
#    Weight_g    Rating
# 0   169.000  4.500000
# 1   182.875  4.700000
# 2   178.000  4.300000
# ...

# %% [markdown]
# # Adding and Removing Data

# %%
df.head()
# Out:
#    Unnamed: 0    Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  \
# 0           0  Samsung     Galaxy S21  $150   4000.000000       128.0    8.00
# 1           1    Apple      iPhone 13  $899   3227.000000       128.0    4.00
# 2           2   Xiaomi  Redmi Note 10  $199   5000.000000        64.0    6.75
# 3           3   Realme       Realme 8  $229   5000.000000       128.0    6.00
# 4           4     Oppo          Reno6  $449   4586.333333       128.0    8.00
#
#    Weight_g    Rating Countries
# 0   169.000  4.500000   Amarica
# 1   182.875  4.700000     China
# 2   178.000  4.300000    Turkey
# 3   177.000  4.400000    Europe
# 4   173.000  4.255556     Italy

# %%
Country  = ['Amarica','China',"Turkey","Europe"]
df['Countries'] = pd.Series(Country)

# %%
df
# Out:
#    Unnamed: 0    Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  \
# 0           0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00
# 1           1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00
# 2           2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75
# 3           3   Realme       Realme 8  $229   5000.000000  128.000000    6.00
# 4           4     Oppo          Reno6  $449   4586.333333  128.000000    8.00
# 5           5     Vivo            Y21  $180   5000.000000   64.000000    4.00
# 6           6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00
# 7           7  Infinix         Zero X  $250   4500.000000  128.000000    8.00
# 8           8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00
# 9           9    Nokia            G20  $160   5050.000000   64.000000    6.75
#
#    Weight_g    Rating Countries
# 0   169.000  4.500000   Amarica
# 1   182.875  4.700000     China
# ...

# %%
df["Countries"].fillna("Italy",inplace= True)
# Out:
# C:\Users\AL Rehman Computer\AppData\Local\Temp\ipykernel_9136\1057306299.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Countries"].fillna("Italy",inplace= True)

# %%
df
# Out:
#    Unnamed: 0    Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  \
# 0           0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00
# 1           1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00
# 2           2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75
# 3           3   Realme       Realme 8  $229   5000.000000  128.000000    6.00
# 4           4     Oppo          Reno6  $449   4586.333333  128.000000    8.00
# 5           5     Vivo            Y21  $180   5000.000000   64.000000    4.00
# 6           6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00
# 7           7  Infinix         Zero X  $250   4500.000000  128.000000    8.00
# 8           8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00
# 9           9    Nokia            G20  $160   5050.000000   64.000000    6.75
#
#    Weight_g    Rating Countries
# 0   169.000  4.500000   Amarica
# 1   182.875  4.700000     China
# ...

# %%
df["Ratio"] =df["Storage_GB"]/df["RAM_GB"]

# %%
df
# Out:
#    Unnamed: 0    Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  \
# 0           0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00
# 1           1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00
# 2           2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75
# 3           3   Realme       Realme 8  $229   5000.000000  128.000000    6.00
# 4           4     Oppo          Reno6  $449   4586.333333  128.000000    8.00
# 5           5     Vivo            Y21  $180   5000.000000   64.000000    4.00
# 6           6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00
# 7           7  Infinix         Zero X  $250   4500.000000  128.000000    8.00
# 8           8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00
# 9           9    Nokia            G20  $160   5050.000000   64.000000    6.75
#
#    Weight_g    Rating Countries      Ratio
# 0   169.000  4.500000   Amarica  16.000000
# ...

# %%
df["NewColumn"] = 3

# %%
df
# Out:
#    Unnamed: 0    Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  \
# 0           0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00
# 1           1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00
# 2           2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75
# 3           3   Realme       Realme 8  $229   5000.000000  128.000000    6.00
# 4           4     Oppo          Reno6  $449   4586.333333  128.000000    8.00
# 5           5     Vivo            Y21  $180   5000.000000   64.000000    4.00
# 6           6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00
# 7           7  Infinix         Zero X  $250   4500.000000  128.000000    8.00
# 8           8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00
# 9           9    Nokia            G20  $160   5050.000000   64.000000    6.75
#
#    Weight_g    Rating Countries      Ratio  NewColumn
# 0   169.000  4.500000   Amarica  16.000000          3
# ...

# %%
df["Safety"] = True

# %%
df
# Out:
#    Unnamed: 0    Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  \
# 0           0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00
# 1           1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00
# 2           2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75
# 3           3   Realme       Realme 8  $229   5000.000000  128.000000    6.00
# 4           4     Oppo          Reno6  $449   4586.333333  128.000000    8.00
# 5           5     Vivo            Y21  $180   5000.000000   64.000000    4.00
# 6           6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00
# 7           7  Infinix         Zero X  $250   4500.000000  128.000000    8.00
# 8           8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00
# 9           9    Nokia            G20  $160   5050.000000   64.000000    6.75
#
#    Weight_g    Rating Countries      Ratio  NewColumn  Safety
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Brand           object
# Model           object
# Price           object
# Battery_mAh    float64
# Storage_GB     float64
# RAM_GB         float64
# Weight_g       float64
# Rating         float64
# Countries       object
# Ratio          float64
# NewColumn        int64
# Safety            bool
# dtype: object

# %%
df.drop("Unnamed: 0" , axis = 1 , inplace=True) #axis = 1 is columns ,,,,axis = 0 is rows

# %%
df
# Out:
#      Brand          Model  Price  Battery_mAh  Storage_GB  RAM_GB  Weight_g  \
# 0  Samsung     Galaxy S21  $150   4000.000000  128.000000    8.00   169.000
# 1    Apple      iPhone 13  $899   3227.000000  128.000000    4.00   182.875
# 2   Xiaomi  Redmi Note 10  $199   5000.000000   64.000000    6.75   178.000
# 3   Realme       Realme 8  $229   5000.000000  128.000000    6.00   177.000
# 4     Oppo          Reno6  $449   4586.333333  128.000000    8.00   173.000
# 5     Vivo            Y21  $180   5000.000000   64.000000    4.00   182.000
# 6  OnePlus          9 Pro  $969   4500.000000   99.555556   12.00   197.000
# 7  Infinix         Zero X  $250   4500.000000  128.000000    8.00   182.875
# 8    Tecno       Camon 17  $150   5000.000000   64.000000    4.00   190.000
# 9    Nokia            G20  $160   5050.000000   64.000000    6.75   197.000
#
#      Rating Countries      Ratio  NewColumn  Safety
# 0  4.500000   Amarica  16.000000          3    True
# ...

# %%
df["Storage_GB"] = df["Storage_GB"].apply(lambda x:x*1000)

# %%
df
# Out:
#      Brand          Model  Price  Battery_mAh     Storage_GB  RAM_GB  \
# 0  Samsung     Galaxy S21  $150   4000.000000  128000.000000    8.00
# 1    Apple      iPhone 13  $899   3227.000000  128000.000000    4.00
# 2   Xiaomi  Redmi Note 10  $199   5000.000000   64000.000000    6.75
# 3   Realme       Realme 8  $229   5000.000000  128000.000000    6.00
# 4     Oppo          Reno6  $449   4586.333333  128000.000000    8.00
# 5     Vivo            Y21  $180   5000.000000   64000.000000    4.00
# 6  OnePlus          9 Pro  $969   4500.000000   99555.555556   12.00
# 7  Infinix         Zero X  $250   4500.000000  128000.000000    8.00
# 8    Tecno       Camon 17  $150   5000.000000   64000.000000    4.00
# 9    Nokia            G20  $160   5050.000000   64000.000000    6.75
#
#    Weight_g    Rating Countries      Ratio  NewColumn  Safety
# 0   169.000  4.500000   Amarica  16.000000          3    True
# 1   182.875  4.700000     China  32.000000          3    True
# ...

# %%
df
# Out:
#      Brand          Model  Price  Battery_mAh     Storage_GB  RAM_GB  \
# 0  Samsung     Galaxy S21  $150   4000.000000  128000.000000    8.00
# 1    Apple      iPhone 13  $899   3227.000000  128000.000000    4.00
# 2   Xiaomi  Redmi Note 10  $199   5000.000000   64000.000000    6.75
# 3   Realme       Realme 8  $229   5000.000000  128000.000000    6.00
# 4     Oppo          Reno6  $449   4586.333333  128000.000000    8.00
# 5     Vivo            Y21  $180   5000.000000   64000.000000    4.00
# 6  OnePlus          9 Pro  $969   4500.000000   99555.555556   12.00
# 7  Infinix         Zero X  $250   4500.000000  128000.000000    8.00
# 8    Tecno       Camon 17  $150   5000.000000   64000.000000    4.00
# 9    Nokia            G20  $160   5050.000000   64000.000000    6.75
#
#    Weight_g    Rating Countries      Ratio  NewColumn  Safety
# 0   169.000  4.500000   Amarica  16.000000          3    True
# 1   182.875  4.700000     China  32.000000          3    True
# ...

# %%
df.groupby("Model")[['Storage_GB','Weight_g']].mean()
# Out:
#                   Storage_GB  Weight_g
# Model
# 9 Pro           99555.555556   197.000
# Camon 17        64000.000000   190.000
# G20             64000.000000   197.000
# Galaxy S21     128000.000000   169.000
# Realme 8       128000.000000   177.000
# Redmi Note 10   64000.000000   178.000
# Reno6          128000.000000   173.000
# Y21             64000.000000   182.000
# Zero X         128000.000000   182.875
# iPhone 13      128000.000000   182.875

# %%
newcomp=df.groupby("Model")[['Storage_GB','Weight_g']].apply(lambda x:x)

# %%
newcomp
# Out:
#                     Storage_GB  Weight_g
# Model
# 9 Pro         6   99555.555556   197.000
# Camon 17      8   64000.000000   190.000
# G20           9   64000.000000   197.000
# Galaxy S21    0  128000.000000   169.000
# Realme 8      3  128000.000000   177.000
# Redmi Note 10 2   64000.000000   178.000
# Reno6         4  128000.000000   173.000
# Y21           5   64000.000000   182.000
# Zero X        7  128000.000000   182.875
# iPhone 13     1  128000.000000   182.875

# %%
df["Storage_GB"].mode()
# Out:
# 0    128000.0
# Name: Storage_GB, dtype: float64
